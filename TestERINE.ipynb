# %%
# -*- encoding: utf-8 -*-
import torch
import torch.nn as nn
import torch.optim as optim
import os
import numpy as np
# import argparse
from torch.utils import data
from torch.utils.data import Dataset

from utils import pad, VOCAB, tag2idx, idx2tag,MAX_LEN,save_model,load_model

#加载自定义模型
# from modules.BBC import Bert_BiGRU_CRF
from crf import Bert_BiLSTM_CRF
# from modules.BIC import BiGRU_CRF,BiLSTM_CRF
# from modules.BC import Bert_CRF
# from modules.ABC import ALNET_BiGRU_CRF
# from modules.RBC import ROBERTA_BiGRU_CRF
# from modules.BBAC import Bert_BiGRU_Attention_CRF
from modules.EBLC import Ernie_BiLSTM_CRF

from modules.BIC import BiGRU_CRF,BiLSTM_CRF
import matplotlib.pyplot as plt
import pytorch_transformers as PyTrans

from pytorch_pretrained_bert import BertTokenizer
#from pytorch_transformers import BertTokenizer as EBertTokenizer
from pytorch_transformers import RobertaTokenizer
from pytorch_transformers import XLNetModel,XLNetTokenizer

# 用来加载日志
import datetime
import logging

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("use device:",device)

LOGPATH="./logs/allmin_v1_"+datetime.datetime.now().strftime('%Y-%m-%d')+".log"
LOGPATH

logging.basicConfig(level=logging.INFO,
                    format="%(asctime)s %(name)s %(levelname)s %(message)s",
#                     datefmt='%a %d %b %Y %H:%M:%S',
                    filename=LOGPATH
                    )
logger = logging.getLogger(__name__)
# Out:
# use device: cuda

# %%
class NerDataset(Dataset):
    def __init__(self, f_path):
        self.tokenizer = BertTokenizer.from_pretrained('chinese_L-12_H-768_A-12')
        with open(f_path, 'r', encoding='utf-8') as fr:
            entries = fr.read().strip().split('\n\n')
        sents, tags_li = [], [] # list of lists
        for entry in entries:
            words = [line.split()[0] for line in entry.splitlines()]
            tags = ([line.split()[-1] for line in entry.splitlines()])
            if len(words) > MAX_LEN:
                # 先对句号分段
                word, tag = [], []
                for char, t in zip(words, tags):
                    
                    if char != '。':
                        if char != '\ue236':   # 测试集中有这个字符
                            word.append(char)
                            tag.append(t)
                    else:
                        sents.append(["[CLS]"] + word[:MAX_LEN] + ["[SEP]"])
                        tags_li.append(['[CLS]'] + tag[:MAX_LEN] + ['[SEP]'])
                        word, tag = [], []            
                # 最后的末尾
                if len(word):
                    sents.append(["[CLS]"] + word[:MAX_LEN] + ["[SEP]"])
                    tags_li.append(['[CLS]'] + tag[:MAX_LEN] + ['[SEP]'])
                    word, tag = [], []
            else:
                sents.append(["[CLS]"] + words[:MAX_LEN] + ["[SEP]"])
                tags_li.append(['[CLS]'] + tags[:MAX_LEN] + ['[SEP]'])
        self.sents, self.tags_li = sents, tags_li
                

    def __getitem__(self, idx):
        words, tags = self.sents[idx], self.tags_li[idx]
        x, y = [], []
        is_heads = []
        for w, t in zip(words, tags):
            tokens = self.tokenizer.tokenize(w) if w not in ("[CLS]", "[SEP]") else [w]
            xx = self.tokenizer.convert_tokens_to_ids(tokens)
            # assert len(tokens) == len(xx), f"len(tokens)={len(tokens)}, len(xx)={len(xx)}"

            # 中文没有英文wordpiece后分成几块的情况
            is_head = [1] + [0]*(len(tokens) - 1)
            t = [t] + ['<PAD>'] * (len(tokens) - 1)
            yy = [tag2idx[each] for each in t]  # (T,)

            x.extend(xx)
            is_heads.extend(is_head)
            y.extend(yy)
        assert len(x)==len(y)==len(is_heads), f"len(x)={len(x)}, len(y)={len(y)}, len(is_heads)={len(is_heads)}"

        # seqlen
        seqlen = len(y)

        # to string
        words = " ".join(words)
        tags = " ".join(tags)
        return words, x, is_heads, tags, y, seqlen


    def __len__(self):
        return len(self.sents)

# %%
class ERNIEDataset(Dataset):
    def __init__(self, f_path):
        self.tokenizer = PyTrans.BertTokenizer.from_pretrained("./ernie-1.0")
        
        with open(f_path, 'r', encoding='utf-8') as fr:
            entries = fr.read().strip().split('\n\n')
        sents, tags_li = [], [] # list of lists
        for entry in entries:
            words = [line.split()[0] for line in entry.splitlines()]
            tags = ([line.split()[-1] for line in entry.splitlines()])
            if len(words) > MAX_LEN:
                # 先对句号分段
                word, tag = [], []
                for char, t in zip(words, tags):
                    
                    if char != '。':
                        if char != '\ue236':   # 测试集中有这个字符
                            word.append(char)
                            tag.append(t)
                    else:
                        sents.append(["[CLS]"] + word[:MAX_LEN] + ["[SEP]"])
                        tags_li.append(['[CLS]'] + tag[:MAX_LEN] + ['[SEP]'])
                        word, tag = [], []            
                # 最后的末尾
                if len(word):
                    sents.append(["[CLS]"] + word[:MAX_LEN] + ["[SEP]"])
                    tags_li.append(['[CLS]'] + tag[:MAX_LEN] + ['[SEP]'])
                    word, tag = [], []
            else:
                sents.append(["[CLS]"] + words[:MAX_LEN] + ["[SEP]"])
                tags_li.append(['[CLS]'] + tags[:MAX_LEN] + ['[SEP]'])
        self.sents, self.tags_li = sents, tags_li
                

    def __getitem__(self, idx):
        
        words, tags = self.sents[idx], self.tags_li[idx]
        x, y = [], []
        is_heads = []
        for w, t in zip(words, tags):
            tokens = self.tokenizer.tokenize(w) if w not in ("[CLS]", "[SEP]") else [w]
            xx = self.tokenizer.convert_tokens_to_ids(tokens)
            # assert len(tokens) == len(xx), f"len(tokens)={len(tokens)}, len(xx)={len(xx)}"

            # 中文没有英文wordpiece后分成几块的情况
            is_head = [1] + [0]*(len(tokens) - 1)
            t = [t] + ['<PAD>'] * (len(tokens) - 1)
            yy = [tag2idx[each] for each in t]  # (T,)

            x.extend(xx)
            is_heads.extend(is_head)
            y.extend(yy)
        assert len(x)==len(y)==len(is_heads), f"len(x)={len(x)}, len(y)={len(y)}, len(is_heads)={len(is_heads)}"

        # seqlen
        seqlen = len(y)

        # to string
        words = " ".join(words)
        tags = " ".join(tags)
        return words, x, is_heads, tags, y, seqlen


    def __len__(self):
        return len(self.sents)

# %%
def train(model, iterator, optimizer, criterion, device):
    model.train()
    for i, batch in enumerate(iterator):
        words, x, is_heads, tags, y, seqlens = batch
        x = x.to(device)
        y = y.to(device)
        _y = y # for monitoring
        optimizer.zero_grad()
        loss = model.neg_log_likelihood(x, y) # logits: (N, T, VOCAB), y: (N, T)

        # logits = logits.view(-1, logits.shape[-1]) # (N*T, VOCAB)
        # y = y.view(-1)  # (N*T,)
        # writer.add_scalar('data/loss', loss.item(), )

        # loss = criterion(logits, y)
        loss.backward()

        optimizer.step()

        # if i==0:
        #     print("=====sanity check======")
        #     #print("words:", words[0])
        #     print("x:", x.cpu().numpy()[0][:seqlens[0]])
        #     # print("tokens:", tokenizer.convert_ids_to_tokens(x.cpu().numpy()[0])[:seqlens[0]])
        #     print("is_heads:", is_heads[0])
        #     print("y:", _y.cpu().numpy()[0][:seqlens[0]])
        #     print("tags:", tags[0])
        #     print("seqlen:", seqlens[0])
        #     print("=======================")

        if i%100==0: # monitoring
            print(f"step: {i}, loss: {loss.item()}")

# %%
from os.path import join
from codecs import open
from collections import Counter

def count_correct_tags(gold_lists,pre_lists):
    """计算每种标签预测正确的个数(对应精确率、召回率计算公式上的tp)，用于后面精确率以及召回率的计算"""
    correct_dict = {}

    for gold_tag, predict_tag in zip(gold_lists, pre_lists):
        if gold_tag == predict_tag:
            if gold_tag not in correct_dict:
                correct_dict[gold_tag] = 1
            else:
                correct_dict[gold_tag] += 1

    return correct_dict



def cal_precision(pre_tags_counter,correct_tags_number,tagset):
    precision_scores = {}
    for tag in tagset:
        if pre_tags_counter[tag] == 0:
            precision_scores[tag] = 0
        else:
            precision_scores[tag] = correct_tags_number.get(tag, 0) / \
                                    pre_tags_counter[tag]

    return precision_scores


def cal_recall(golden_tags_counter,correct_tags_number,tagset):
    recall_scores = {}
    for tag in tagset:
        recall_scores[tag] = correct_tags_number.get(tag, 0) / \
                             golden_tags_counter[tag]
    return recall_scores


def cal_f1(precision_scores,recall_scores,tagset):
    f1_scores = {}
    for tag in tagset:
        p, r = precision_scores[tag], recall_scores[tag]
        f1_scores[tag] = 2 * p * r / (p + r + 1e-10)  # 加上一个特别小的数，防止分母为0
    return f1_scores


def report_scores(precision_scores,recall_scores,f1_scores,golden_tags_counter,gold_lists,tagset):
    """将结果用表格的形式打印出来，像这个样子：

                  precision    recall  f1-score   support
          B-LOC      0.775     0.757     0.766      1084
          I-LOC      0.601     0.631     0.616       325
         B-MISC      0.698     0.499     0.582       339
         I-MISC      0.644     0.567     0.603       557
          B-ORG      0.795     0.801     0.798      1400
          I-ORG      0.831     0.773     0.801      1104
          B-PER      0.812     0.876     0.843       735
          I-PER      0.873     0.931     0.901       634

      avg/total      0.779     0.764     0.770      6178
    """
    # 打印表头
    header_format = '{:>9s}  {:>9} {:>9} {:>9} {:>9}'
    header = ['precision', 'recall', 'f1-score', 'support']
    print(header_format.format('', *header))

    row_format = '{:>9s}  {:>9.4f} {:>9.4f} {:>9.4f} {:>9}'
    # 打印每个标签的 精确率、召回率、f1分数
    for tag in tagset:
        print(row_format.format(
            tag,
            precision_scores[tag],
            recall_scores[tag],
            f1_scores[tag],
            golden_tags_counter[tag]
        ))

    # 计算并打印平均值
    avg_metrics = cal_weighted_average(precision_scores,recall_scores,f1_scores,golden_tags_counter,gold_lists,tagset)
    print(row_format.format(
        'avg/total',
        avg_metrics['precision'],
        avg_metrics['recall'],
        avg_metrics['f1_score'],
        len(gold_lists)
    ))


def cal_weighted_average(precision_scores,recall_scores,f1_scores,golden_tags_counter,gold_lists,tagset):
    weighted_average = {}
    total = len(gold_lists)

    # 计算weighted precisions:
    weighted_average['precision'] = 0.
    weighted_average['recall'] = 0.
    weighted_average['f1_score'] = 0.
    for tag in tagset:
        size = golden_tags_counter[tag]
        weighted_average['precision'] += precision_scores[tag] * size
        weighted_average['recall'] += recall_scores[tag] * size
        weighted_average['f1_score'] += f1_scores[tag] * size

    for metric in weighted_average.keys():
        weighted_average[metric] /= total

    return weighted_average


def remove_Otags(gold_lists,pre_lists):

    length = len(gold_lists)

    O_tag_indices = [i for i in range(length)
                     if gold_lists[i] == 'O']

    gold_lists = [tag for i, tag in enumerate(gold_lists)
                        if i not in O_tag_indices]

    pre_lists = [tag for i, tag in enumerate(pre_lists)
                         if i not in O_tag_indices]
    print("原总标记数为{}，移除了{}个O标记，占比{:.2f}%".format(
        length,
        len(O_tag_indices),
        len(O_tag_indices) / length * 100
    ))

    return gold_lists,pre_lists

def get_entities(seq):
    """
    Gets entities from sequence.

    Args:
        seq (list): sequence of labels.

    Returns:
        list: list of (chunk_type, chunk_start, chunk_end).

    Example:
        seq = ['B-PER', 'I-PER', 'O', 'B-LOC']
        get_entities(seq)
        [('PER', 0, 1), ('LOC', 3, 3)]
    """
    # for nested list
    if any(isinstance(s, list) for s in seq):
        seq = [item for sublist in seq for item in sublist + ['O']]
    prev_tag = 'O'
    prev_type = ''
    begin_offset = 0
    chunks = []
    for i, chunk in enumerate(seq + ['O']):
        tag = chunk[0]
        type_ = chunk.split('-')[-1]

        if end_of_chunk(prev_tag, tag, prev_type, type_):
            chunks.append((prev_type, begin_offset, i - 1))
        if start_of_chunk(prev_tag, tag, prev_type, type_):
            begin_offset = i
        prev_tag = tag
        prev_type = type_

    return chunks


def end_of_chunk(prev_tag, tag, prev_type, type_):
    """Checks if a chunk ended between the previous and current word.

    Args:
        prev_tag: previous chunk tag.
        tag: current chunk tag.
        prev_type: previous type.
        type_: current type.

    Returns:
        chunk_end: boolean.
    """
    chunk_end = False

    if prev_tag == 'S':
        chunk_end = True
    if prev_tag == 'E':
        chunk_end = True
    # pred_label中可能出现这种情形
    if prev_tag == 'B' and tag == 'B':
        chunk_end = True
    if prev_tag == 'B' and tag == 'S':
        chunk_end = True
    if prev_tag == 'B' and tag == 'O':
        chunk_end = True
    if prev_tag == 'M' and tag == 'B':
        chunk_end = True
    if prev_tag == 'M' and tag == 'S':
        chunk_end = True
    if prev_tag == 'M' and tag == 'O':
        chunk_end = True

    if prev_tag != 'O' and prev_tag != '.' and prev_type != type_:
        chunk_end = True

    return chunk_end


def start_of_chunk(prev_tag, tag, prev_type, type_):
    """Checks if a chunk started between the previous and current word.

    Args:
        prev_tag: previous chunk tag.
        tag: current chunk tag.
        prev_type: previous type.
        type_: current type.

    Returns:
        chunk_start: boolean.
    """
    chunk_start = False

    if tag == 'B':
        chunk_start = True
    if tag == 'S':
        chunk_start = True

    if prev_tag == 'S' and tag == 'M':
        chunk_start = True
    if prev_tag == 'O' and tag == 'M':
        chunk_start = True
    if prev_tag == 'S' and tag == 'E':
        chunk_start = True
    if prev_tag == 'O' and tag == 'E':
        chunk_start = True

    if tag != 'O' and tag != '.' and prev_type != type_:
        chunk_start = True

    return chunk_start


def f1_score(y_true, y_pred, labels, mode='dev'):

    true_entities = set(get_entities(y_true))
    pred_entities = set(get_entities(y_pred))
    nb_correct = len(true_entities & pred_entities)
    nb_pred = len(pred_entities)
    nb_true = len(true_entities)

    true_entities_num = {'NAME': 0, 'TYPE': 0, 'ENV': 0, 'FEA': 0, 'SUR': 0, 'EVA': 0, 'DEF': 0}
    #true_entities_num = {'CONT': 0, 'TITLE': 0, 'EDU': 0, 'ORG': 0, 'LOC': 0, 'PRO': 0, 'RACE': 0,'NAME':0}
    for entity in true_entities:
        tag = entity[0]
        true_entities_num[tag] += 1

    p = nb_correct / nb_pred if nb_pred > 0 else 0
    r = nb_correct / nb_true if nb_true > 0 else 0
    score = 2 * p * r / (p + r) if p + r > 0 else 0
    if mode == 'dev':
        return score
    else:
        f_score = {}
        precision_scores = {}
        recall_scores = {}
        for label in labels:
            true_entities_label = set()
            pred_entities_label = set()
            for t in true_entities:
                if t[0] == label:
                    true_entities_label.add(t)
            for p in pred_entities:
                if p[0] == label:
                    pred_entities_label.add(p)
            nb_correct_label = len(true_entities_label & pred_entities_label)
            nb_pred_label = len(pred_entities_label)
            nb_true_label = len(true_entities_label)

            p_label = nb_correct_label / nb_pred_label if nb_pred_label > 0 else 0
            r_label = nb_correct_label / nb_true_label if nb_true_label > 0 else 0
            score_label = 2 * p_label * r_label / (p_label + r_label) if p_label + r_label > 0 else 0
            f_score[label] = score_label
            precision_scores[label] = p_label
            recall_scores[label] = r_label

        weighted_average = {}
        total = nb_true

        # 计算weighted precisions:
        weighted_average['precision'] = 0.
        weighted_average['recall'] = 0.
        weighted_average['f1_score'] = 0.
        for tag in labels:
            size = true_entities_num[tag]
            weighted_average['precision'] += precision_scores[tag] * size
            weighted_average['recall'] += recall_scores[tag] * size
            weighted_average['f1_score'] += f_score[tag] * size

        for metric in weighted_average.keys():
            weighted_average[metric] /= total

        header_format = '{:>9s}  {:>9} {:>9} {:>9} {:>9}'
        header = ['precision', 'recall', 'f1-score', 'support']
        print("-------------------Entities Report------------------")
        print(header_format.format('', *header))

        row_format = '{:>9s}  {:>9.4f} {:>9.4f} {:>9.4f} {:>9}'
        # 打印每个标签的 精确率、召回率、f1分数
        for tag in labels:
            print(row_format.format(
                tag,
                precision_scores[tag],
                recall_scores[tag],
                f_score[tag],
                true_entities_num[tag]
            ))
        print(row_format.format(
            'avg/total',
            weighted_average['precision'],
            weighted_average['recall'],
            weighted_average['f1_score'],
            total
        ))
        print("-------------------Labels Report----- -------------")

        return weighted_average

# %%
def eval(model, iterator, f, device,temp:str, isEnd=False):
#     print("temp:"+temp)
    model.eval()

    Words, Is_heads, Tags, Y, Y_hat = [], [], [], [], []
    with torch.no_grad():
        for i, batch in enumerate(iterator):
            words, x, is_heads, tags, y, seqlens = batch
            x = x.to(device)
            # y = y.to(device)

            _, y_hat = model(x)  # y_hat: (N, T)

            Words.extend(words)
            Is_heads.extend(is_heads)
            Tags.extend(tags)
            Y.extend(y.numpy().tolist())
            Y_hat.extend(y_hat.cpu().numpy().tolist())

    ## gets results and save
    with open(temp, 'w', encoding='utf-8') as fout:
        for words, is_heads, tags, y_hat in zip(Words, Is_heads, Tags, Y_hat):
            y_hat = [hat for head, hat in zip(is_heads, y_hat) if head == 1]
            preds = [idx2tag[hat] for hat in y_hat]
            assert len(preds)==len(words.split())==len(tags.split())
            for w, t, p in zip(words.split()[1:-1], tags.split()[1:-1], preds[1:-1]):
                fout.write(f"{w} {t} {p}\n")
            fout.write("\n")

    word_lists = []
    gold_lists = []
    pre_lists = []
    
    with open(temp, 'r', encoding='utf-8') as f:
        for line in f:
            if line != '\n':
                word, gold, pre = line.strip('\n').split()
                #print(word, ' ' + gold, '' + pre)
                word_lists.append(word)
                gold_lists.append(gold)
                pre_lists.append(pre)
    
    
    
    labels = ['NAME', 'TYPE', 'ENV', 'FEA', 'SUR', 'EVA', 'DEF']
    avg=f1_score(gold_lists, pre_lists, labels, mode='test')
#     gold_lists,pre_lists=remove_Otags(gold_lists,pre_lists)
#     tagset = set(gold_lists)
#     correct_tags_number = count_correct_tags(gold_lists,pre_lists)
#     pre_tags_counter = Counter(pre_lists)
#     golden_tags_counter = Counter(gold_lists)
#     precision_scores = cal_precision(pre_tags_counter,correct_tags_number,tagset)
#     recall_scores = cal_recall(golden_tags_counter,correct_tags_number,tagset)
#     f1_scores = cal_f1(precision_scores,recall_scores,tagset)
#     avg = cal_weighted_average(precision_scores,recall_scores,f1_scores,golden_tags_counter,gold_lists,tagset)
#     report_scores(precision_scores,recall_scores,f1_scores,golden_tags_counter,gold_lists,tagset)
    

    if isEnd!=True:
        os.remove(temp)

#     print("precision=%.4f"%precision)
#     print("recall=%.4f"%recall)
#     print("f1=%.4f"%f1)
    return avg['precision'],avg['recall'], avg['f1_score']

# %%
def run(LOGDIR="checkpoints/01",TRAINSET="data/gqp.train",VALIDSET="data/gqp.dev",TESTSET="data/test.txt.anns",BATCH_SIZE=5,LR=0.001,N_EPOCHS=30):

    
    PRFS=[]
    modelnames = [
#         "bert_bigru_attention_crf",
                  "ernie_bilstm_crf",
                "bert_bilstm_crf",
#                "bilstm_crf",
#                "bigru_crf",
#                "bert_crf",
                "bilstm_crf"
#                "alnet_bilstm_crf"
            ]
    models =  [ 
#                 (Bert_BiGRU_Attention_CRF(tag2idx).to(device),"bert_bigru_attention_crf_temp"),
#                (Ernie_BiLSTM_CRF(tag2idx).to(device),"ernie_bilstm_crf_temp")
                (Ernie_BiLSTM_CRF(tag2idx).to(device),"ernie_bilstm_crf_temp"),
                (Bert_BiLSTM_CRF(tag2idx).to(device),"bert_bilstm_crf_temp")
#                ,(BiLSTM_CRF(tag2idx).to(device),"bilstm_crf_temp")
#                ,(BiGRU_CRF(tag2idx).to(device),"bigru_crf_temp")
#                ,(Bert_CRF(tag2idx).to(device),"bert_crf_temp")
                ,(BiLSTM_CRF(tag2idx).to(device),"bilstm_crf_temp")     
#                (ALNET_BiLSTM_CRF(tag2idx).to(device),"alnet_bilstm_crf_temp")
                ]
        
    for index,(currentmodel,currentmodeltemp) in enumerate(models):
        train_iter,eval_iter = None,None
        
        # 根据模型名称加载对应的模型数据
        if modelnames[index] in ["bert_bilstm_crf","bilstm_crf"]:
            train_dataset = NerDataset(TRAINSET)
            eval_dataset = NerDataset(VALIDSET)
            test_dataset = NerDataset(TESTSET)
            train_iter = data.DataLoader(dataset=train_dataset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True,
                                 num_workers=8,
                                 collate_fn=pad)
            eval_iter = data.DataLoader(dataset=eval_dataset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True,
                                 num_workers=8,
                                 collate_fn=pad)
            test_iter = data.DataLoader(dataset=test_dataset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True,
                                 num_workers=8,
                                 collate_fn=pad)
            logger.info(f"{modelnames[index]}匹配到NerDataset")
            
        elif modelnames[index] in ["roberta_bilstm_crf"]:
            
            train_dataset = RoBERTaDataset(TRAINSET)
            eval_dataset = RoBERTaDataset(VALIDSET)
            test_dataset = RoBERTaDataset(TESTSET)
            train_iter = data.DataLoader(dataset=train_dataset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True,
                                 num_workers=3,
                                 collate_fn=pad)
            eval_iter = data.DataLoader(dataset=eval_dataset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True,
                                 num_workers=3,
                                 collate_fn=pad)
            test_iter = data.DataLoader(dataset=test_dataset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True,
                                 num_workers=3,
                                 collate_fn=pad)
            logger.info(f"{modelnames[index]}匹配到RoBERTaDataset")
            
        elif modelnames[index] in ["alnet_bilstm_crf"]:
            train_dataset = XlNetDataset(TRAINSET)
            eval_dataset = XlNetDataset(VALIDSET)
            test_dataset = XlNetDataset(TESTSET)
            train_iter = data.DataLoader(dataset=train_dataset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True,
                                 num_workers=3,
                                 collate_fn=pad)
            eval_iter = data.DataLoader(dataset=eval_dataset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True,
                                 num_workers=3,
                                 collate_fn=pad)
            test_iter = data.DataLoader(dataset=test_dataset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True,
                                 num_workers=3,
                                 collate_fn=pad)
            logger.info(f"{modelnames[index]}匹配到XlNetDataset")
            
        elif modelnames[index] in ["albert_bilstm_crf"]:
            
            train_dataset = AlBERTDataset(TRAINSET)
            eval_dataset = AlBERTDataset(VALIDSET)
            test_dataset = AlBERTDataset(TESTSET)
            train_iter = data.DataLoader(dataset=train_dataset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True,
                                 num_workers=3,
                                 collate_fn=pad)
            eval_iter = data.DataLoader(dataset=eval_dataset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True,
                                 num_workers=3,
                                 collate_fn=pad)
            test_iter = data.DataLoader(dataset=test_dataset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True,
                                 num_workers=3,
                                 collate_fn=pad)
            logger.info(f"{modelnames[index]}匹配到AlBERTDataset")
            
        elif modelnames[index] in ["ernie_bilstm_crf"]:
            
            train_dataset = ERNIEDataset(TRAINSET)
            eval_dataset = ERNIEDataset(VALIDSET)
            test_dataset = ERNIEDataset(TESTSET)
            train_iter = data.DataLoader(dataset=train_dataset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True,
                                 num_workers=8,
                                 collate_fn=pad)
            eval_iter = data.DataLoader(dataset=eval_dataset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True,
                                 num_workers=8,
                                 collate_fn=pad)
            test_iter = data.DataLoader(dataset=test_dataset,
                                 batch_size=BATCH_SIZE,
                                 shuffle=True,
                                 num_workers=8,
                                 collate_fn=pad)
            logger.info(f"{modelnames[index]}匹配到ERNIEDataset")
        else:
            logger.warning(f"{modelnames[index]}没有匹配到模型的数据")
        
        
        
#         print("="*30+"begin "+ currentmodelname + "="*30)
        optimizer = optim.Adam(currentmodel.parameters(), lr = LR)
        criterion = nn.CrossEntropyLoss(ignore_index=0) 
        for epoch in range(1, N_EPOCHS+1):  # 每个epoch对dev集进行测试
            
            print("=========epoch= {} ===model= {} =========".format(epoch,modelnames[index]))
            train(currentmodel, train_iter, optimizer, criterion, device)
            print("-----------save model= {} ---------------".format(modelnames[index]))
            torch.save(currentmodel.state_dict(), "./savemodels/"+modelnames[index]+".pkl")
            #save_model(currentmodel, "./savemodels/"+modelnames[index]+".pkl")
            if not os.path.exists(LOGDIR): os.makedirs(LOGDIR)
            fname = os.path.join(LOGDIR, str(epoch))
            precision, recall, f1 = eval(currentmodel, eval_iter, fname, device,currentmodeltemp,isEnd=False)
            logger.info("modelname=%s,epoch=%03d,precision=%.4f,recall=%.4f,f1=%.4f"%(modelnames[index],epoch,precision, recall, f1))
            if epoch == N_EPOCHS:
                print("========= Test ===model= {} ============".format(modelnames[index]))
                eval(currentmodel, test_iter, fname, device,currentmodeltemp,isEnd=True)
                PRFS.append([precision, recall, f1])
            
#         print("="*30+"end "+ currentmodelname + "="*30)
    return PRFS

# %%
modelNames = [ "ernie_bilstm_crf","bert_bilstm_crf","bilstm_crf"]

# %%
iters=[]
# range(10,210,10)
# current=None
#iterLength=[*range(1,2,1)]
# iterLength=[*range(1,12,2)]
# for thisIter in iterLength:
# #     print(thisIter)
    
#     current=run(LOGDIR="checkpoints/01",TRAINSET="data/train.txt.anns",VALIDSET="data/dev.txt.anns",BATCH_SIZE=20,LR=5e-5,N_EPOCHS=thisIter)
#     iters.append(current)
# # print(iters)
# iters = np.array(iters)
# # iters
current=run(LOGDIR="checkpoints/01",TRAINSET="data/train.txt.anns",VALIDSET="data/dev.txt.anns",TESTSET="data/test.txt.anns",
            BATCH_SIZE=64,LR=5e-5,N_EPOCHS=100)
# Out:
# =========epoch= 1 ===model= ernie_bilstm_crf =========
# step: 0, loss: 10378.1669921875
# step: 100, loss: 9888.634765625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.0000    0.0000    0.0000        61
#      TYPE     0.0000    0.0000    0.0000       135
#       ENV     0.0000    0.0000    0.0000      1691
#       FEA     0.0000    0.0000    0.0000      1427
#       SUR     0.0000    0.0000    0.0000        59
#       EVA     0.0000    0.0000    0.0000       484
#       DEF     0.0000    0.0000    0.0000       174
# avg/total     0.0000    0.0000    0.0000      4031
# -------------------Labels Report----- -------------
# =========epoch= 2 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9878.193359375
# step: 100, loss: 9873.6640625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.0000    0.0000    0.0000        61
#      TYPE     0.0000    0.0000    0.0000       135
#       ENV     0.0256    0.0006    0.0012      1691
#       FEA     0.0000    0.0000    0.0000      1427
#       SUR     0.0000    0.0000    0.0000        59
#       EVA     0.0000    0.0000    0.0000       484
#       DEF     0.0000    0.0000    0.0000       174
# avg/total     0.0108    0.0002    0.0005      4031
# -------------------Labels Report----- -------------
# =========epoch= 3 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9863.58984375
# step: 100, loss: 9854.6748046875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.0000    0.0000    0.0000        61
#      TYPE     0.0000    0.0000    0.0000       135
#       ENV     0.0998    0.1135    0.1062      1691
#       FEA     0.0047    0.0077    0.0059      1427
#       SUR     0.0000    0.0000    0.0000        59
#       EVA     0.0333    0.0062    0.0105       484
#       DEF     0.0000    0.0000    0.0000       174
# avg/total     0.0475    0.0511    0.0479      4031
# -------------------Labels Report----- -------------
# =========epoch= 4 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9849.9150390625
# step: 100, loss: 9838.998046875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.0000    0.0000    0.0000        61
#      TYPE     0.0000    0.0000    0.0000       135
#       ENV     0.1260    0.1449    0.1348      1691
#       FEA     0.1381    0.2235    0.1707      1427
#       SUR     0.0000    0.0000    0.0000        59
#       EVA     0.1176    0.0331    0.0516       484
#       DEF     0.0000    0.0000    0.0000       174
# avg/total     0.1159    0.1439    0.1232      4031
# -------------------Labels Report----- -------------
# =========epoch= 5 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9839.21484375
# step: 100, loss: 9826.794921875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.0075    0.0164    0.0103        61
#      TYPE     0.0000    0.0000    0.0000       135
#       ENV     0.2939    0.3323    0.3120      1691
#       FEA     0.2914    0.3973    0.3362      1427
#       SUR     0.0000    0.0000    0.0000        59
#       EVA     0.1140    0.1012    0.1072       484
#       DEF     0.0000    0.0000    0.0000       174
# avg/total     0.2402    0.2925    0.2629      4031
# -------------------Labels Report----- -------------
# =========epoch= 6 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9822.6357421875
# step: 100, loss: 9819.025390625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.0609    0.1148    0.0795        61
#      TYPE     0.0000    0.0000    0.0000       135
#       ENV     0.4888    0.5157    0.5019      1691
#       FEA     0.4231    0.5340    0.4721      1427
#       SUR     0.1200    0.0508    0.0714        59
#       EVA     0.1444    0.1901    0.1641       484
#       DEF     0.0086    0.0057    0.0069       174
# avg/total     0.3752    0.4309    0.3999      4031
# -------------------Labels Report----- -------------
# =========epoch= 7 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9812.357421875
# step: 100, loss: 9802.7197265625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.0776    0.1475    0.1017        61
#      TYPE     0.0000    0.0000    0.0000       135
#       ENV     0.5926    0.6623    0.6255      1691
#       FEA     0.5200    0.7099    0.6003      1427
#       SUR     0.1667    0.1017    0.1263        59
#       EVA     0.1212    0.1467    0.1327       484
#       DEF     0.0261    0.0230    0.0245       174
# avg/total     0.4520    0.5515    0.4953      4031
# -------------------Labels Report----- -------------
# =========epoch= 8 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9805.1650390625
# step: 100, loss: 9797.19921875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.0860    0.1311    0.1039        61
#      TYPE     0.0000    0.0000    0.0000       135
#       ENV     0.6578    0.7457    0.6990      1691
#       FEA     0.5769    0.7127    0.6376      1427
#       SUR     0.0909    0.0678    0.0777        59
#       EVA     0.1603    0.2438    0.1934       484
#       DEF     0.0292    0.0230    0.0257       174
# avg/total     0.5033    0.5984    0.5460      4031
# -------------------Labels Report----- -------------
# =========epoch= 9 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9794.123046875
# step: 100, loss: 9789.7255859375
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.0641    0.0820    0.0719        61
#      TYPE     0.0069    0.0074    0.0072       135
#       ENV     0.6987    0.7516    0.7242      1691
#       FEA     0.6131    0.7106    0.6582      1427
#       SUR     0.2051    0.1356    0.1633        59
#       EVA     0.1993    0.2231    0.2105       484
#       DEF     0.0574    0.0402    0.0473       174
# avg/total     0.5408    0.5989    0.5679      4031
# -------------------Labels Report----- -------------
# =========epoch= 10 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9787.9912109375
# step: 100, loss: 9780.91015625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.0941    0.1311    0.1096        61
#      TYPE     0.0600    0.0667    0.0632       135
#       ENV     0.7305    0.8161    0.7709      1691
#       FEA     0.6725    0.7814    0.7229      1427
#       SUR     0.2927    0.2034    0.2400        59
#       EVA     0.3271    0.3988    0.3594       484
#       DEF     0.1579    0.1379    0.1472       174
# avg/total     0.5983    0.6800    0.6361      4031
# -------------------Labels Report----- -------------
# =========epoch= 11 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9776.337890625
# step: 100, loss: 9773.693359375
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.1319    0.1967    0.1579        61
#      TYPE     0.2202    0.2741    0.2442       135
#       ENV     0.7355    0.8533    0.7900      1691
#       FEA     0.6953    0.8220    0.7534      1427
#       SUR     0.3111    0.2373    0.2692        59
#       EVA     0.4071    0.5434    0.4655       484
#       DEF     0.2947    0.3218    0.3077       174
# avg/total     0.6302    0.7437    0.6818      4031
# -------------------Labels Report----- -------------
# =========epoch= 12 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9771.4140625
# step: 100, loss: 9766.4453125
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.1600    0.2623    0.1988        61
#      TYPE     0.3875    0.4593    0.4203       135
#       ENV     0.7899    0.8782    0.8317      1691
#       FEA     0.7300    0.8297    0.7766      1427
#       SUR     0.3400    0.2881    0.3119        59
#       EVA     0.4819    0.5496    0.5135       484
#       DEF     0.3636    0.3218    0.3415       174
# avg/total     0.6837    0.7656    0.7219      4031
# -------------------Labels Report----- -------------
# =========epoch= 13 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9761.791015625
# step: 100, loss: 9756.2880859375
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.1146    0.1803    0.1401        61
#      TYPE     0.4375    0.5185    0.4746       135
#       ENV     0.8161    0.8451    0.8303      1691
#       FEA     0.7445    0.8290    0.7845      1427
#       SUR     0.3125    0.2542    0.2804        59
#       EVA     0.5269    0.6074    0.5643       484
#       DEF     0.4641    0.4080    0.4343       174
# avg/total     0.7102    0.7623    0.7347      4031
# -------------------Labels Report----- -------------
# =========epoch= 14 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9754.275390625
# step: 100, loss: 9748.224609375
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.1959    0.3115    0.2405        61
#      TYPE     0.4933    0.5481    0.5193       135
#       ENV     0.8256    0.8989    0.8607      1691
#       FEA     0.7713    0.8486    0.8081      1427
#       SUR     0.4800    0.4068    0.4404        59
#       EVA     0.5662    0.5393    0.5524       484
#       DEF     0.4671    0.4080    0.4356       174
# avg/total     0.7341    0.7889    0.7598      4031
# -------------------Labels Report----- -------------
# =========epoch= 15 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9747.12109375
# step: 100, loss: 9739.466796875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.2300    0.3770    0.2857        61
#      TYPE     0.5828    0.6519    0.6154       135
#       ENV     0.8276    0.9001    0.8623      1691
#       FEA     0.7773    0.8486    0.8114      1427
#       SUR     0.4286    0.3559    0.3889        59
#       EVA     0.5672    0.6364    0.5998       484
#       DEF     0.5271    0.3908    0.4488       174
# avg/total     0.7425    0.8040    0.7710      4031
# -------------------Labels Report----- -------------
# =========epoch= 16 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9586.259765625
# step: 100, loss: 9733.767578125
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.1509    0.2623    0.1916        61
#      TYPE     0.6463    0.7037    0.6738       135
#       ENV     0.8650    0.8906    0.8776      1691
#       FEA     0.7923    0.8339    0.8126      1427
#       SUR     0.5435    0.4237    0.4762        59
#       EVA     0.6008    0.6591    0.6286       484
#       DEF     0.6441    0.4368    0.5205       174
# avg/total     0.7752    0.8005    0.7862      4031
# -------------------Labels Report----- -------------
# =========epoch= 17 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9730.0458984375
# step: 100, loss: 9725.5283203125
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.3069    0.5082    0.3827        61
#      TYPE     0.6689    0.7481    0.7063       135
#       ENV     0.8623    0.8888    0.8754      1691
#       FEA     0.7978    0.8655    0.8303      1427
#       SUR     0.6735    0.5593    0.6111        59
#       EVA     0.6120    0.6550    0.6327       484
#       DEF     0.6327    0.5345    0.5794       174
# avg/total     0.7819    0.8219    0.8005      4031
# -------------------Labels Report----- -------------
# =========epoch= 18 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9722.333984375
# step: 100, loss: 9717.609375
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.4022    0.6066    0.4837        61
#      TYPE     0.6467    0.7185    0.6807       135
#       ENV     0.8737    0.8959    0.8847      1691
#       FEA     0.8153    0.8753    0.8442      1427
#       SUR     0.7200    0.6102    0.6606        59
#       EVA     0.6039    0.6426    0.6226       484
#       DEF     0.6831    0.5575    0.6139       174
# avg/total     0.7954    0.8291    0.8110      4031
# -------------------Labels Report----- -------------
# =========epoch= 19 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9714.025390625
# step: 100, loss: 9709.3525390625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.3900    0.6393    0.4845        61
#      TYPE     0.7273    0.8296    0.7751       135
#       ENV     0.8514    0.9213    0.8850      1691
#       FEA     0.7961    0.8893    0.8401      1427
#       SUR     0.7193    0.6949    0.7069        59
#       EVA     0.6379    0.7169    0.6751       484
#       DEF     0.6022    0.6437    0.6222       174
# avg/total     0.7823    0.8628    0.8202      4031
# -------------------Labels Report----- -------------
# =========epoch= 20 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9705.99609375
# step: 100, loss: 9701.8984375
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.4643    0.6393    0.5379        61
#      TYPE     0.7055    0.7630    0.7331       135
#       ENV     0.8745    0.9231    0.8982      1691
#       FEA     0.8111    0.8816    0.8449      1427
#       SUR     0.7021    0.5593    0.6226        59
#       EVA     0.6324    0.6612    0.6465       484
#       DEF     0.6853    0.5632    0.6183       174
# avg/total     0.8004    0.8464    0.8220      4031
# -------------------Labels Report----- -------------
# =========epoch= 21 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9697.46484375
# step: 100, loss: 9691.447265625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.5158    0.8033    0.6282        61
#      TYPE     0.7987    0.8815    0.8380       135
#       ENV     0.8740    0.9267    0.8995      1691
#       FEA     0.8048    0.8984    0.8490      1427
#       SUR     0.7755    0.6441    0.7037        59
#       EVA     0.6422    0.7045    0.6719       484
#       DEF     0.6688    0.5920    0.6280       174
# avg/total     0.8034    0.8680    0.8336      4031
# -------------------Labels Report----- -------------
# =========epoch= 22 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9690.947265625
# step: 100, loss: 9684.09765625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.4138    0.5902    0.4865        61
#      TYPE     0.7517    0.8296    0.7887       135
#       ENV     0.8795    0.9320    0.9050      1691
#       FEA     0.8166    0.8893    0.8514      1427
#       SUR     0.7292    0.5932    0.6542        59
#       EVA     0.6569    0.7397    0.6958       484
#       DEF     0.6512    0.6437    0.6474       174
# avg/total     0.8071    0.8678    0.8359      4031
# -------------------Labels Report----- -------------
# =========epoch= 23 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9680.9736328125
# step: 100, loss: 9676.1962890625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.4600    0.7541    0.5714        61
#      TYPE     0.7881    0.8815    0.8322       135
#       ENV     0.8727    0.9243    0.8978      1691
#       FEA     0.8209    0.8802    0.8495      1427
#       SUR     0.7292    0.5932    0.6542        59
#       EVA     0.6660    0.7045    0.6847       484
#       DEF     0.6766    0.6494    0.6628       174
# avg/total     0.8099    0.8616    0.8343      4031
# -------------------Labels Report----- -------------
# =========epoch= 24 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9674.66796875
# step: 100, loss: 9668.392578125
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.4839    0.7377    0.5844        61
#      TYPE     0.7838    0.8593    0.8198       135
#       ENV     0.8730    0.9349    0.9029      1691
#       FEA     0.8231    0.8641    0.8431      1427
#       SUR     0.7091    0.6610    0.6842        59
#       EVA     0.6735    0.7417    0.7060       484
#       DEF     0.6707    0.6437    0.6569       174
# avg/total     0.8114    0.8645    0.8367      4031
# -------------------Labels Report----- -------------
# =========epoch= 25 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9664.423828125
# step: 100, loss: 9660.5556640625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.4688    0.7377    0.5732        61
#      TYPE     0.8207    0.8815    0.8500       135
#       ENV     0.8989    0.9249    0.9117      1691
#       FEA     0.8082    0.9033    0.8531      1427
#       SUR     0.6613    0.6949    0.6777        59
#       EVA     0.6822    0.7273    0.7040       484
#       DEF     0.6946    0.6667    0.6804       174
# avg/total     0.8193    0.8747    0.8454      4031
# -------------------Labels Report----- -------------
# =========epoch= 26 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9502.9853515625
# step: 100, loss: 9652.275390625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.4673    0.8197    0.5952        61
#      TYPE     0.7933    0.8815    0.8351       135
#       ENV     0.8978    0.9249    0.9112      1691
#       FEA     0.8226    0.8739    0.8474      1427
#       SUR     0.7193    0.6949    0.7069        59
#       EVA     0.6883    0.7665    0.7253       484
#       DEF     0.7081    0.6552    0.6806       174
# avg/total     0.8252    0.8698    0.8460      4031
# -------------------Labels Report----- -------------
# =========epoch= 27 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9648.4384765625
# step: 100, loss: 9640.513671875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.4500    0.5902    0.5106        61
#      TYPE     0.7667    0.8519    0.8070       135
#       ENV     0.8981    0.9326    0.9150      1691
#       FEA     0.8241    0.8865    0.8542      1427
#       SUR     0.6739    0.5254    0.5905        59
#       EVA     0.6841    0.7562    0.7184       484
#       DEF     0.7383    0.6322    0.6811       174
# avg/total     0.8248    0.8683    0.8453      4031
# -------------------Labels Report----- -------------
# =========epoch= 28 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9638.677734375
# step: 100, loss: 9633.537109375
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.4167    0.8197    0.5525        61
#      TYPE     0.7636    0.9333    0.8400       135
#       ENV     0.8518    0.9415    0.8944      1691
#       FEA     0.7710    0.9061    0.8331      1427
#       SUR     0.5890    0.7288    0.6515        59
#       EVA     0.6331    0.7913    0.7034       484
#       DEF     0.5622    0.8046    0.6619       174
# avg/total     0.7711    0.8998    0.8292      4031
# -------------------Labels Report----- -------------
# =========epoch= 29 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9630.4775390625
# step: 100, loss: 9624.744140625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.5000    0.6885    0.5793        61
#      TYPE     0.8014    0.8667    0.8327       135
#       ENV     0.9118    0.9107    0.9112      1691
#       FEA     0.8346    0.8949    0.8637      1427
#       SUR     0.7959    0.6610    0.7222        59
#       EVA     0.7017    0.7727    0.7355       484
#       DEF     0.7110    0.7069    0.7089       174
# avg/total     0.8390    0.8712    0.8542      4031
# -------------------Labels Report----- -------------
# =========epoch= 30 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9620.9892578125
# step: 100, loss: 9615.2529296875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6250    0.8197    0.7092        61
#      TYPE     0.8092    0.9111    0.8571       135
#       ENV     0.8788    0.9391    0.9079      1691
#       FEA     0.8163    0.9033    0.8576      1427
#       SUR     0.7636    0.7119    0.7368        59
#       EVA     0.7013    0.7521    0.7258       484
#       DEF     0.7052    0.7011    0.7032       174
# avg/total     0.8200    0.8876    0.8522      4031
# -------------------Labels Report----- -------------
# =========epoch= 31 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9611.21484375
# step: 100, loss: 9606.923828125
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6494    0.8197    0.7246        61
#      TYPE     0.8095    0.8815    0.8440       135
#       ENV     0.8972    0.9397    0.9180      1691
#       FEA     0.8386    0.8991    0.8678      1427
#       SUR     0.7049    0.7288    0.7167        59
#       EVA     0.7287    0.7603    0.7442       484
#       DEF     0.7582    0.6667    0.7095       174
# avg/total     0.8407    0.8851    0.8620      4031
# -------------------Labels Report----- -------------
# =========epoch= 32 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9602.63671875
# step: 100, loss: 9596.36328125
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.5253    0.8525    0.6500        61
#      TYPE     0.8146    0.9111    0.8601       135
#       ENV     0.8986    0.9385    0.9181      1691
#       FEA     0.8359    0.8963    0.8651      1427
#       SUR     0.6984    0.7458    0.7213        59
#       EVA     0.7025    0.8099    0.7524       484
#       DEF     0.6931    0.7529    0.7218       174
# avg/total     0.8326    0.8951    0.8621      4031
# -------------------Labels Report----- -------------
# =========epoch= 33 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9593.9755859375
# step: 100, loss: 9587.537109375
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.5579    0.8689    0.6795        61
#      TYPE     0.8255    0.9111    0.8662       135
#       ENV     0.9131    0.9379    0.9253      1691
#       FEA     0.8268    0.8998    0.8617      1427
#       SUR     0.7288    0.7288    0.7288        59
#       EVA     0.6932    0.8264    0.7540       484
#       DEF     0.6816    0.7874    0.7307       174
# avg/total     0.8351    0.8995    0.8653      4031
# -------------------Labels Report----- -------------
# =========epoch= 34 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9584.611328125
# step: 100, loss: 9578.5703125
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6143    0.7049    0.6565        61
#      TYPE     0.8182    0.8667    0.8417       135
#       ENV     0.9196    0.9261    0.9228      1691
#       FEA     0.8373    0.8690    0.8528      1427
#       SUR     0.7931    0.7797    0.7863        59
#       EVA     0.7222    0.8058    0.7617       484
#       DEF     0.7127    0.7414    0.7268       174
# avg/total     0.8479    0.8760    0.8615      4031
# -------------------Labels Report----- -------------
# =========epoch= 35 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9575.556640625
# step: 100, loss: 9570.6328125
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.5595    0.7705    0.6483        61
#      TYPE     0.8138    0.8741    0.8429       135
#       ENV     0.9179    0.9326    0.9252      1691
#       FEA     0.8458    0.9033    0.8736      1427
#       SUR     0.8000    0.6780    0.7339        59
#       EVA     0.7490    0.7583    0.7536       484
#       DEF     0.7730    0.6264    0.6921       174
# avg/total     0.8552    0.8799    0.8665      4031
# -------------------Labels Report----- -------------
# =========epoch= 36 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9565.515625
# step: 100, loss: 9559.8046875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.5446    0.9016    0.6790        61
#      TYPE     0.8276    0.8889    0.8571       135
#       ENV     0.9155    0.9420    0.9286      1691
#       FEA     0.8393    0.9075    0.8721      1427
#       SUR     0.7586    0.7458    0.7521        59
#       EVA     0.7370    0.8223    0.7773       484
#       DEF     0.7053    0.7701    0.7363       174
# avg/total     0.8472    0.9028    0.8734      4031
# -------------------Labels Report----- -------------
# =========epoch= 37 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9557.10546875
# step: 100, loss: 9551.732421875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.5556    0.8197    0.6623        61
#      TYPE     0.8514    0.9333    0.8905       135
#       ENV     0.9126    0.9391    0.9257      1691
#       FEA     0.8382    0.9110    0.8731      1427
#       SUR     0.6984    0.7458    0.7213        59
#       EVA     0.7320    0.8182    0.7727       484
#       DEF     0.7320    0.8161    0.7717       174
# avg/total     0.8462    0.9045    0.8739      4031
# -------------------Labels Report----- -------------
# =========epoch= 38 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9546.623046875
# step: 100, loss: 9540.6015625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.5474    0.8525    0.6667        61
#      TYPE     0.8345    0.8963    0.8643       135
#       ENV     0.9184    0.9385    0.9283      1691
#       FEA     0.8399    0.8970    0.8675      1427
#       SUR     0.7627    0.7627    0.7627        59
#       EVA     0.7490    0.8140    0.7802       484
#       DEF     0.7318    0.7529    0.7422       174
# avg/total     0.8515    0.8956    0.8725      4031
# -------------------Labels Report----- -------------
# =========epoch= 39 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9536.958984375
# step: 100, loss: 9530.251953125
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.5698    0.8033    0.6667        61
#      TYPE     0.8276    0.8889    0.8571       135
#       ENV     0.9085    0.9391    0.9235      1691
#       FEA     0.8554    0.8914    0.8730      1427
#       SUR     0.8302    0.7458    0.7857        59
#       EVA     0.7392    0.8140    0.7748       484
#       DEF     0.7544    0.7414    0.7478       174
# avg/total     0.8537    0.8921    0.8721      4031
# -------------------Labels Report----- -------------
# =========epoch= 40 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9527.7080078125
# step: 100, loss: 9521.47265625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.5870    0.8852    0.7059        61
#      TYPE     0.8224    0.9259    0.8711       135
#       ENV     0.8989    0.9409    0.9194      1691
#       FEA     0.8539    0.9012    0.8769      1427
#       SUR     0.7460    0.7966    0.7705        59
#       EVA     0.6971    0.8368    0.7606       484
#       DEF     0.6950    0.7989    0.7433       174
# avg/total     0.8404    0.9047    0.8707      4031
# -------------------Labels Report----- -------------
# =========epoch= 41 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9517.9775390625
# step: 100, loss: 9510.271484375
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6282    0.8033    0.7050        61
#      TYPE     0.8194    0.8741    0.8459       135
#       ENV     0.9112    0.9349    0.9229      1691
#       FEA     0.8495    0.8858    0.8672      1427
#       SUR     0.8462    0.7458    0.7928        59
#       EVA     0.7209    0.8326    0.7728       484
#       DEF     0.8075    0.7471    0.7761       174
# avg/total     0.8537    0.8903    0.8711      4031
# -------------------Labels Report----- -------------
# =========epoch= 42 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9508.3984375
# step: 100, loss: 9501.146484375
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6125    0.8033    0.6950        61
#      TYPE     0.8425    0.9111    0.8754       135
#       ENV     0.9211    0.9456    0.9332      1691
#       FEA     0.8588    0.9075    0.8825      1427
#       SUR     0.8113    0.7288    0.7679        59
#       EVA     0.7665    0.7934    0.7797       484
#       DEF     0.8129    0.7241    0.7660       174
# avg/total     0.8669    0.8978    0.8816      4031
# -------------------Labels Report----- -------------
# =========epoch= 43 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9498.935546875
# step: 100, loss: 9491.34765625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.5684    0.8852    0.6923        61
#      TYPE     0.8345    0.8963    0.8643       135
#       ENV     0.9168    0.9450    0.9307      1691
#       FEA     0.8554    0.9075    0.8807      1427
#       SUR     0.8000    0.7458    0.7719        59
#       EVA     0.7306    0.8182    0.7719       484
#       DEF     0.7418    0.7759    0.7584       174
# avg/total     0.8554    0.9037    0.8783      4031
# -------------------Labels Report----- -------------
# =========epoch= 44 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9488.51171875
# step: 100, loss: 9481.650390625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6709    0.8689    0.7571        61
#      TYPE     0.8311    0.9111    0.8693       135
#       ENV     0.9121    0.9391    0.9254      1691
#       FEA     0.8623    0.9040    0.8827      1427
#       SUR     0.8235    0.7119    0.7636        59
#       EVA     0.7462    0.8202    0.7815       484
#       DEF     0.7939    0.7529    0.7729       174
# avg/total     0.8618    0.8990    0.8796      4031
# -------------------Labels Report----- -------------
# =========epoch= 45 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9478.3623046875
# step: 100, loss: 9471.73046875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.7324    0.8525    0.7879        61
#      TYPE     0.8521    0.8963    0.8736       135
#       ENV     0.9227    0.9456    0.9340      1691
#       FEA     0.8650    0.9026    0.8834      1427
#       SUR     0.8400    0.7119    0.7706        59
#       EVA     0.7586    0.8182    0.7873       484
#       DEF     0.7901    0.7356    0.7619       174
# avg/total     0.8704    0.8995    0.8844      4031
# -------------------Labels Report----- -------------
# =========epoch= 46 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9468.2802734375
# step: 100, loss: 9460.9990234375
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6923    0.8852    0.7770        61
#      TYPE     0.8562    0.9259    0.8897       135
#       ENV     0.9199    0.9373    0.9285      1691
#       FEA     0.8681    0.9131    0.8900      1427
#       SUR     0.8148    0.7458    0.7788        59
#       EVA     0.7566    0.8285    0.7909       484
#       DEF     0.7903    0.8448    0.8167       174
# avg/total     0.8692    0.9077    0.8878      4031
# -------------------Labels Report----- -------------
# =========epoch= 47 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9458.4775390625
# step: 100, loss: 9451.48828125
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.7027    0.8525    0.7704        61
#      TYPE     0.8542    0.9111    0.8817       135
#       ENV     0.9242    0.9450    0.9345      1691
#       FEA     0.8651    0.8942    0.8794      1427
#       SUR     0.7593    0.6949    0.7257        59
#       EVA     0.7756    0.7996    0.7874       484
#       DEF     0.8148    0.7586    0.7857       174
# avg/total     0.8726    0.8953    0.8836      4031
# -------------------Labels Report----- -------------
# =========epoch= 48 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9448.111328125
# step: 100, loss: 9441.9775390625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6709    0.8689    0.7571        61
#      TYPE     0.8345    0.8963    0.8643       135
#       ENV     0.9072    0.9480    0.9271      1691
#       FEA     0.8703    0.9075    0.8885      1427
#       SUR     0.8148    0.7458    0.7788        59
#       EVA     0.7510    0.8099    0.7793       484
#       DEF     0.7811    0.7586    0.7697       174
# avg/total     0.8626    0.9030    0.8821      4031
# -------------------Labels Report----- -------------
# =========epoch= 49 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9437.7265625
# step: 100, loss: 9431.5498046875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.7647    0.8525    0.8062        61
#      TYPE     0.8143    0.8444    0.8291       135
#       ENV     0.9254    0.9385    0.9319      1691
#       FEA     0.8645    0.9075    0.8855      1427
#       SUR     0.8627    0.7458    0.8000        59
#       EVA     0.7876    0.7893    0.7884       484
#       DEF     0.8366    0.7356    0.7829       174
# avg/total     0.8764    0.8936    0.8845      4031
# -------------------Labels Report----- -------------
# =========epoch= 50 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9427.603515625
# step: 100, loss: 9421.1044921875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6098    0.8197    0.6993        61
#      TYPE     0.8483    0.9111    0.8786       135
#       ENV     0.9232    0.9456    0.9343      1691
#       FEA     0.8672    0.9061    0.8862      1427
#       SUR     0.8462    0.7458    0.7928        59
#       EVA     0.7782    0.7975    0.7878       484
#       DEF     0.8182    0.7759    0.7965       174
# avg/total     0.8731    0.9005    0.8862      4031
# -------------------Labels Report----- -------------
# =========epoch= 51 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9417.8876953125
# step: 100, loss: 9411.416015625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.7105    0.8852    0.7883        61
#      TYPE     0.8333    0.9259    0.8772       135
#       ENV     0.9174    0.9462    0.9316      1691
#       FEA     0.8389    0.9047    0.8705      1427
#       SUR     0.7377    0.7627    0.7500        59
#       EVA     0.7636    0.8140    0.7880       484
#       DEF     0.7389    0.8621    0.7958       174
# avg/total     0.8549    0.9077    0.8802      4031
# -------------------Labels Report----- -------------
# =========epoch= 52 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9408.6435546875
# step: 100, loss: 9400.51171875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.7000    0.8033    0.7481        61
#      TYPE     0.8681    0.9259    0.8961       135
#       ENV     0.9172    0.9497    0.9332      1691
#       FEA     0.8562    0.8844    0.8700      1427
#       SUR     0.8113    0.7288    0.7679        59
#       EVA     0.7704    0.8182    0.7936       484
#       DEF     0.7874    0.7874    0.7874       174
# avg/total     0.8659    0.8975    0.8813      4031
# -------------------Labels Report----- -------------
# =========epoch= 53 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9398.28515625
# step: 100, loss: 9390.1650390625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6795    0.8689    0.7626        61
#      TYPE     0.8200    0.9111    0.8632       135
#       ENV     0.9190    0.9462    0.9324      1691
#       FEA     0.8486    0.9075    0.8771      1427
#       SUR     0.7627    0.7627    0.7627        59
#       EVA     0.7616    0.8120    0.7860       484
#       DEF     0.8023    0.8161    0.8091       174
# avg/total     0.8609    0.9057    0.8825      4031
# -------------------Labels Report----- -------------
# =========epoch= 54 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9387.16796875
# step: 100, loss: 9380.736328125
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6364    0.9180    0.7517        61
#      TYPE     0.8378    0.9185    0.8763       135
#       ENV     0.9205    0.9444    0.9323      1691
#       FEA     0.8618    0.9047    0.8827      1427
#       SUR     0.7797    0.7797    0.7797        59
#       EVA     0.7649    0.7934    0.7789       484
#       DEF     0.7680    0.7989    0.7831       174
# avg/total     0.8653    0.9023    0.8830      4031
# -------------------Labels Report----- -------------
# =========epoch= 55 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9228.3740234375
# step: 100, loss: 9370.48046875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6753    0.8525    0.7536        61
#      TYPE     0.8493    0.9185    0.8826       135
#       ENV     0.9253    0.9456    0.9354      1691
#       FEA     0.8703    0.9075    0.8885      1427
#       SUR     0.8000    0.7458    0.7719        59
#       EVA     0.7570    0.8368    0.7949       484
#       DEF     0.7989    0.8448    0.8212       174
# avg/total     0.8720    0.9095    0.8901      4031
# -------------------Labels Report----- -------------
# =========epoch= 56 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9366.458984375
# step: 100, loss: 9359.81640625
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6163    0.8689    0.7211        61
#      TYPE     0.8741    0.9259    0.8993       135
#       ENV     0.9336    0.9403    0.9369      1691
#       FEA     0.8737    0.9159    0.8943      1427
#       SUR     0.8246    0.7966    0.8103        59
#       EVA     0.7771    0.8140    0.7952       484
#       DEF     0.8059    0.7874    0.7965       174
# avg/total     0.8797    0.9062    0.8924      4031
# -------------------Labels Report----- -------------
# =========epoch= 57 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9356.1611328125
# step: 100, loss: 9350.05078125
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6835    0.8852    0.7714        61
#      TYPE     0.8333    0.9259    0.8772       135
#       ENV     0.9200    0.9527    0.9361      1691
#       FEA     0.8558    0.9068    0.8806      1427
#       SUR     0.8136    0.8136    0.8136        59
#       EVA     0.7542    0.8430    0.7961       484
#       DEF     0.7641    0.8563    0.8076       174
# avg/total     0.8626    0.9152    0.8878      4031
# -------------------Labels Report----- -------------
# =========epoch= 58 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9346.19140625
# step: 100, loss: 9339.732421875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.7647    0.8525    0.8062        61
#      TYPE     0.8483    0.9111    0.8786       135
#       ENV     0.9293    0.9480    0.9385      1691
#       FEA     0.8717    0.8949    0.8831      1427
#       SUR     0.7963    0.7288    0.7611        59
#       EVA     0.7789    0.8079    0.7931       484
#       DEF     0.8228    0.7471    0.7831       174
# avg/total     0.8791    0.8978    0.8881      4031
# -------------------Labels Report----- -------------
# =========epoch= 59 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9335.130859375
# step: 100, loss: 9330.318359375
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.7083    0.8361    0.7669        61
#      TYPE     0.8310    0.8741    0.8520       135
#       ENV     0.9227    0.9533    0.9378      1691
#       FEA     0.8700    0.8914    0.8806      1427
#       SUR     0.7963    0.7288    0.7611        59
#       EVA     0.7869    0.7934    0.7901       484
#       DEF     0.8442    0.7471    0.7927       174
# avg/total     0.8762    0.8956    0.8855      4031
# -------------------Labels Report----- -------------
# =========epoch= 60 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9325.4111328125
# step: 100, loss: 9318.046875
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.7794    0.8689    0.8217        61
#      TYPE     0.8552    0.9185    0.8857       135
#       ENV     0.9257    0.9426    0.9341      1691
#       FEA     0.8784    0.8907    0.8845      1427
#       SUR     0.7581    0.7966    0.7769        59
#       EVA     0.7824    0.8244    0.8028       484
#       DEF     0.8424    0.7989    0.8201       174
# avg/total     0.8811    0.8998    0.8902      4031
# -------------------Labels Report----- -------------
# =========epoch= 61 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9314.935546875
# step: 100, loss: 9308.1923828125
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.7222    0.8525    0.7820        61
#      TYPE     0.8811    0.9333    0.9065       135
#       ENV     0.9382    0.9426    0.9404      1691
#       FEA     0.8791    0.9117    0.8951      1427
#       SUR     0.7885    0.6949    0.7387        59
#       EVA     0.7859    0.7810    0.7834       484
#       DEF     0.8354    0.7874    0.8107       174
# avg/total     0.8872    0.9003    0.8934      4031
# -------------------Labels Report----- -------------
# =========epoch= 62 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9304.7158203125
# step: 100, loss: 9296.7734375
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6627    0.9016    0.7639        61
#      TYPE     0.8421    0.9481    0.8920       135
#       ENV     0.9304    0.9403    0.9353      1691
#       FEA     0.8606    0.9082    0.8837      1427
#       SUR     0.7344    0.7966    0.7642        59
#       EVA     0.7551    0.8347    0.7929       484
#       DEF     0.7772    0.8621    0.8174       174
# avg/total     0.8681    0.9104    0.8883      4031
# -------------------Labels Report----- -------------
# =========epoch= 63 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9293.46875
# step: 100, loss: 9286.53125
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.7424    0.8033    0.7717        61
#      TYPE     0.8311    0.9111    0.8693       135
#       ENV     0.9303    0.9474    0.9388      1691
#       FEA     0.8767    0.8970    0.8867      1427
#       SUR     0.8070    0.7797    0.7931        59
#       EVA     0.7878    0.7975    0.7926       484
#       DEF     0.8171    0.8218    0.8195       174
# avg/total     0.8814    0.9003    0.8907      4031
# -------------------Labels Report----- -------------
# =========epoch= 64 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9283.5732421875
# step: 100, loss: 9276.42578125
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.6627    0.9016    0.7639        61
#      TYPE     0.8611    0.9185    0.8889       135
#       ENV     0.9282    0.9480    0.9380      1691
#       FEA     0.8506    0.9173    0.8827      1427
#       SUR     0.8103    0.7966    0.8034        59
#       EVA     0.7736    0.8120    0.7923       484
#       DEF     0.8239    0.8333    0.8286       174
# avg/total     0.8697    0.9119    0.8899      4031
# -------------------Labels Report----- -------------
# =========epoch= 65 ===model= ernie_bilstm_crf =========
# step: 0, loss: 9273.181640625
# step: 100, loss: 9266.8818359375
# -----------save model= ernie_bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.7429    0.8525    0.7939        61
#      TYPE     0.8643    0.8963    0.8800       135
#       ENV     0.9364    0.9403    0.9383      1691
#       FEA     0.8866    0.9040    0.8952      1427
#       SUR     0.8103    0.7966    0.8034        59
#       EVA     0.7780    0.8182    0.7976       484
#       DEF     0.8156    0.8391    0.8272       174
# avg/total     0.8873    0.9035    0.8953      4031
# -------------------Labels Report----- -------------
# =========epoch= 66 ===model= ernie_bilstm_crf =========
# ...
# avg/total     0.8924    0.9055    0.8988      4031
# -------------------Labels Report----- -------------
# =========epoch= 80 ===model= bilstm_crf =========
# step: 0, loss: 9098.8544921875
# step: 100, loss: 9092.138671875
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8387    0.8525    0.8455        61
#      TYPE     0.8881    0.9407    0.9137       135
#       ENV     0.9292    0.9474    0.9382      1691
#       FEA     0.8805    0.9194    0.8996      1427
#       SUR     0.6712    0.8305    0.7424        59
#       EVA     0.8040    0.8388    0.8210       484
#       DEF     0.8333    0.8333    0.8333       174
# avg/total     0.8863    0.9161    0.9008      4031
# -------------------Labels Report----- -------------
# =========epoch= 81 ===model= bilstm_crf =========
# step: 0, loss: 9088.1630859375
# step: 100, loss: 9081.103515625
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8281    0.8689    0.8480        61
#      TYPE     0.8944    0.9407    0.9170       135
#       ENV     0.9304    0.9480    0.9391      1691
#       FEA     0.8924    0.9124    0.9023      1427
#       SUR     0.7143    0.8475    0.7752        59
#       EVA     0.8101    0.8285    0.8192       484
#       DEF     0.8363    0.8218    0.8290       174
# avg/total     0.8925    0.9127    0.9024      4031
# -------------------Labels Report----- -------------
# =========epoch= 82 ===model= bilstm_crf =========
# step: 0, loss: 9077.5302734375
# step: 100, loss: 9070.19921875
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8387    0.8525    0.8455        61
#      TYPE     0.8873    0.9333    0.9097       135
#       ENV     0.9245    0.9480    0.9361      1691
#       FEA     0.8933    0.8977    0.8955      1427
#       SUR     0.7273    0.8136    0.7680        59
#       EVA     0.8004    0.8450    0.8221       484
#       DEF     0.8462    0.8218    0.8338       174
# avg/total     0.8897    0.9085    0.8989      4031
# -------------------Labels Report----- -------------
# =========epoch= 83 ===model= bilstm_crf =========
# step: 0, loss: 9066.9130859375
# step: 100, loss: 9059.701171875
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8814    0.8525    0.8667        61
#      TYPE     0.9085    0.9556    0.9314       135
#       ENV     0.9287    0.9403    0.9345      1691
#       FEA     0.8922    0.9159    0.9039      1427
#       SUR     0.6857    0.8136    0.7442        59
#       EVA     0.8004    0.8285    0.8142       484
#       DEF     0.8034    0.8218    0.8125       174
# avg/total     0.8900    0.9104    0.9000      4031
# -------------------Labels Report----- -------------
# =========epoch= 84 ===model= bilstm_crf =========
# step: 0, loss: 8912.3203125
# step: 100, loss: 9048.8544921875
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8548    0.8689    0.8618        61
#      TYPE     0.9071    0.9407    0.9236       135
#       ENV     0.9331    0.9409    0.9370      1691
#       FEA     0.8835    0.9145    0.8988      1427
#       SUR     0.8167    0.8305    0.8235        59
#       EVA     0.8195    0.8347    0.8270       484
#       DEF     0.7901    0.8218    0.8056       174
# avg/total     0.8920    0.9109    0.9013      4031
# -------------------Labels Report----- -------------
# =========epoch= 85 ===model= bilstm_crf =========
# step: 0, loss: 9045.74609375
# step: 100, loss: 9038.59375
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.9153    0.8852    0.9000        61
#      TYPE     0.9085    0.9556    0.9314       135
#       ENV     0.9328    0.9444    0.9386      1691
#       FEA     0.8866    0.9152    0.9007      1427
#       SUR     0.6901    0.8305    0.7538        59
#       EVA     0.8136    0.8388    0.8260       484
#       DEF     0.8304    0.8161    0.8232       174
# avg/total     0.8931    0.9137    0.9031      4031
# -------------------Labels Report----- -------------
# =========epoch= 86 ===model= bilstm_crf =========
# step: 0, loss: 9034.9765625
# step: 100, loss: 9027.556640625
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8814    0.8525    0.8667        61
#      TYPE     0.8865    0.9259    0.9058       135
#       ENV     0.9328    0.9438    0.9383      1691
#       FEA     0.8786    0.8879    0.8832      1427
#       SUR     0.7385    0.8136    0.7742        59
#       EVA     0.7963    0.8079    0.8021       484
#       DEF     0.8650    0.8103    0.8368       174
# avg/total     0.8891    0.8980    0.8935      4031
# -------------------Labels Report----- -------------
# =========epoch= 87 ===model= bilstm_crf =========
# step: 0, loss: 9024.134765625
# step: 100, loss: 9017.0576171875
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8030    0.8689    0.8346        61
#      TYPE     0.9149    0.9556    0.9348       135
#       ENV     0.9314    0.9480    0.9396      1691
#       FEA     0.8748    0.9159    0.8949      1427
#       SUR     0.6579    0.8475    0.7407        59
#       EVA     0.8107    0.8492    0.8295       484
#       DEF     0.8033    0.8448    0.8235       174
# avg/total     0.8849    0.9179    0.9009      4031
# -------------------Labels Report----- -------------
# =========epoch= 88 ===model= bilstm_crf =========
# step: 0, loss: 9014.611328125
# step: 100, loss: 9006.146484375
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.9138    0.8689    0.8908        61
#      TYPE     0.9209    0.9481    0.9343       135
#       ENV     0.9302    0.9385    0.9344      1691
#       FEA     0.8999    0.9075    0.9037      1427
#       SUR     0.7313    0.8305    0.7778        59
#       EVA     0.8171    0.8306    0.8238       484
#       DEF     0.8304    0.8161    0.8232       174
# avg/total     0.8981    0.9070    0.9025      4031
# -------------------Labels Report----- -------------
# =========epoch= 89 ===model= bilstm_crf =========
# step: 0, loss: 9002.90234375
# step: 100, loss: 8995.3876953125
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8644    0.8361    0.8500        61
#      TYPE     0.9124    0.9259    0.9191       135
#       ENV     0.9312    0.9444    0.9378      1691
#       FEA     0.8836    0.9047    0.8940      1427
#       SUR     0.7581    0.7966    0.7769        59
#       EVA     0.8025    0.8058    0.8041       484
#       DEF     0.8434    0.8046    0.8235       174
# avg/total     0.8909    0.9032    0.8970      4031
# -------------------Labels Report----- -------------
# =========epoch= 90 ===model= bilstm_crf =========
# step: 0, loss: 8992.013671875
# step: 100, loss: 8985.1494140625
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8966    0.8525    0.8739        61
#      TYPE     0.8978    0.9111    0.9044       135
#       ENV     0.9270    0.9391    0.9330      1691
#       FEA     0.8746    0.8753    0.8750      1427
#       SUR     0.7231    0.7966    0.7581        59
#       EVA     0.8176    0.8244    0.8210       484
#       DEF     0.8313    0.7644    0.7964       174
# avg/total     0.8868    0.8908    0.8887      4031
# -------------------Labels Report----- -------------
# =========epoch= 91 ===model= bilstm_crf =========
# step: 0, loss: 8981.61328125
# step: 100, loss: 8974.0625
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8644    0.8361    0.8500        61
#      TYPE     0.9203    0.9407    0.9304       135
#       ENV     0.9292    0.9474    0.9382      1691
#       FEA     0.8743    0.9166    0.8950      1427
#       SUR     0.7246    0.8475    0.7812        59
#       EVA     0.8160    0.8430    0.8293       484
#       DEF     0.8333    0.8046    0.8187       174
# avg/total     0.8878    0.9144    0.9008      4031
# -------------------Labels Report----- -------------
# =========epoch= 92 ===model= bilstm_crf =========
# step: 0, loss: 8970.7236328125
# step: 100, loss: 8964.00390625
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8197    0.8197    0.8197        61
#      TYPE     0.8944    0.9407    0.9170       135
#       ENV     0.9150    0.9480    0.9312      1691
#       FEA     0.8729    0.8949    0.8837      1427
#       SUR     0.7463    0.8475    0.7937        59
#       EVA     0.8184    0.8099    0.8141       484
#       DEF     0.8125    0.8218    0.8171       174
# avg/total     0.8794    0.9035    0.8912      4031
# -------------------Labels Report----- -------------
# =========epoch= 93 ===model= bilstm_crf =========
# step: 0, loss: 8960.1279296875
# step: 100, loss: 8952.49609375
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8361    0.8361    0.8361        61
#      TYPE     0.9143    0.9481    0.9309       135
#       ENV     0.9282    0.9480    0.9380      1691
#       FEA     0.8856    0.9222    0.9035      1427
#       SUR     0.7937    0.8475    0.8197        59
#       EVA     0.8164    0.8450    0.8305       484
#       DEF     0.8167    0.8448    0.8305       174
# avg/total     0.8910    0.9189    0.9047      4031
# -------------------Labels Report----- -------------
# =========epoch= 94 ===model= bilstm_crf =========
# step: 0, loss: 8949.4716796875
# step: 100, loss: 8941.861328125
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8667    0.8525    0.8595        61
#      TYPE     0.9085    0.9556    0.9314       135
#       ENV     0.9349    0.9515    0.9431      1691
#       FEA     0.8979    0.9117    0.9047      1427
#       SUR     0.8448    0.8305    0.8376        59
#       EVA     0.8211    0.8347    0.8279       484
#       DEF     0.8204    0.7874    0.8035       174
# avg/total     0.9000    0.9132    0.9065      4031
# -------------------Labels Report----- -------------
# =========epoch= 95 ===model= bilstm_crf =========
# step: 0, loss: 8938.552734375
# step: 100, loss: 8931.5078125
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8197    0.8197    0.8197        61
#      TYPE     0.9137    0.9407    0.9270       135
#       ENV     0.9323    0.9450    0.9386      1691
#       FEA     0.8864    0.9131    0.8996      1427
#       SUR     0.7246    0.8475    0.7812        59
#       EVA     0.8165    0.8368    0.8265       484
#       DEF     0.8256    0.8161    0.8208       174
# avg/total     0.8922    0.9117    0.9018      4031
# -------------------Labels Report----- -------------
# =========epoch= 96 ===model= bilstm_crf =========
# step: 0, loss: 8927.837890625
# step: 100, loss: 8920.89453125
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8333    0.8197    0.8264        61
#      TYPE     0.9058    0.9259    0.9158       135
#       ENV     0.9389    0.9450    0.9419      1691
#       FEA     0.8947    0.9054    0.9000      1427
#       SUR     0.7059    0.8136    0.7559        59
#       EVA     0.8172    0.8223    0.8198       484
#       DEF     0.8415    0.7931    0.8166       174
# avg/total     0.8983    0.9052    0.9017      4031
# -------------------Labels Report----- -------------
# =========epoch= 97 ===model= bilstm_crf =========
# step: 0, loss: 8917.33984375
# step: 100, loss: 8909.6455078125
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8730    0.9016    0.8871        61
#      TYPE     0.8803    0.9259    0.9025       135
#       ENV     0.9157    0.9509    0.9330      1691
#       FEA     0.8887    0.9005    0.8945      1427
#       SUR     0.7812    0.8475    0.8130        59
#       EVA     0.8144    0.8430    0.8284       484
#       DEF     0.8034    0.8218    0.8125       174
# avg/total     0.8853    0.9114    0.8981      4031
# -------------------Labels Report----- -------------
# =========epoch= 98 ===model= bilstm_crf =========
# step: 0, loss: 8906.369140625
# step: 100, loss: 8899.279296875
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8621    0.8197    0.8403        61
#      TYPE     0.9058    0.9259    0.9158       135
#       ENV     0.9386    0.9491    0.9438      1691
#       FEA     0.8950    0.9138    0.9043      1427
#       SUR     0.7903    0.8305    0.8099        59
#       EVA     0.8271    0.8202    0.8237       484
#       DEF     0.8538    0.8391    0.8464       174
# avg/total     0.9017    0.9119    0.9067      4031
# -------------------Labels Report----- -------------
# =========epoch= 99 ===model= bilstm_crf =========
# step: 0, loss: 8895.748046875
# step: 100, loss: 8888.66015625
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8644    0.8361    0.8500        61
#      TYPE     0.9007    0.9407    0.9203       135
#       ENV     0.9323    0.9444    0.9383      1691
#       FEA     0.8967    0.9124    0.9045      1427
#       SUR     0.7869    0.8136    0.8000        59
#       EVA     0.8162    0.8347    0.8253       484
#       DEF     0.8333    0.8046    0.8187       174
# avg/total     0.8973    0.9102    0.9036      4031
# -------------------Labels Report----- -------------
# =========epoch= 100 ===model= bilstm_crf =========
# step: 0, loss: 8884.91015625
# step: 100, loss: 8877.501953125
# -----------save model= bilstm_crf ---------------
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8814    0.8525    0.8667        61
#      TYPE     0.8921    0.9185    0.9051       135
#       ENV     0.9369    0.9486    0.9427      1691
#       FEA     0.9011    0.9131    0.9071      1427
#       SUR     0.7656    0.8305    0.7967        59
#       EVA     0.8067    0.8017    0.8041       484
#       DEF     0.8535    0.7701    0.8097       174
# avg/total     0.9001    0.9065    0.9032      4031
# -------------------Labels Report----- -------------
# ========= Test ===model= bilstm_crf ============
# -------------------Entities Report------------------
#            precision    recall  f1-score   support
#      NAME     0.8625    0.8734    0.8679        79
#      TYPE     0.9562    0.9225    0.9391       142
#       ENV     0.9391    0.9470    0.9430      1792
#       FEA     0.8797    0.9068    0.8930      1459
#       SUR     0.9167    0.8354    0.8742        79
#       EVA     0.8117    0.7996    0.8056       469
#       DEF     0.8449    0.8103    0.8272       195
# avg/total     0.8987    0.9060    0.9022      4215
# -------------------Labels Report----- -------------
